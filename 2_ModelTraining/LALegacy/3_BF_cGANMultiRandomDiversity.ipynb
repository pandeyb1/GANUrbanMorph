# %% [markdown]
# # 3 BF Multi-Random Diversity cGAN
#
# Self-contained Colab notebook for `3_BF_cGANMultiRandomDiversity`. Outputs are written to `/content/drive/My Drive/IM3/EvalP1/codev3/3_BF_cGANMultiRandomDiversity` with fixed run folders.

# %%
import torch
print("3 BF Multi-Random Diversity cGAN")
print("Using torch", torch.__version__)
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("No GPU detected. In Colab, use Runtime > Change runtime type > GPU.")

# !nvidia-smi
# Out:
# 3 BF Multi-Random Diversity cGAN
# Using torch 2.11.0+cu128
# GPU: NVIDIA A100-SXM4-80GB
# Mon Jun 22 14:16:12 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   31C    P0             51W /  400W |       6MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import csv
import json
import random
import shutil
import subprocess
import sys
import time
import zipfile
from dataclasses import asdict, dataclass
from pathlib import Path
from typing import Iterable, Optional

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset

# %%
# =============================================================================
# Colab configuration. Edit only paths/hyperparameters here if needed.
# =============================================================================

MODEL_CLASS = "3_BF_cGANMultiRandomDiversity"
TARGET_KIND = "bf"
CONDITION_KIND = "lulc"

INSTALL_RASTERIO_IF_MISSING = True
MOUNT_GOOGLE_DRIVE = True

DRIVE_ARCHIVE_ZIP = "/content/drive/My Drive/IM3/Full/Archive.zip"
COPY_ARCHIVE_TO_LOCAL_BEFORE_EXTRACT = True
LOCAL_ARCHIVE_ZIP = "/content/Archive.zip"
EXTRACT_ARCHIVE_IF_NEEDED = True
EXTRACT_DIR = "/home"

CONDITION_DIR = "/home/central"
TARGET_DIR = "/home/BFrac"
OUTPUT_ROOT = "/content/drive/My Drive/IM3/EvalP1/codev3"
OUTPUT_SUBDIR = "3_BF_cGANMultiRandomDiversity"

LULC_MODE = "raw"
NLCD_CLASSES = (
    11, 12, 21, 22, 23, 24, 31, 41,
    42, 43, 52, 71, 81, 82, 90, 95,
)

HEIGHT_UNITS = "feet"
MAX_HEIGHT_M = 75.0

LEARNING_RATES = [0.0001, 0.0002, 0.0005, 0.001]
EPOCHS = 1000
BATCH_SIZE = 128
NUM_WORKERS = 12
SAVE_EVERY = 250
PRINT_EVERY = 25
CACHE_DATA_IN_RAM = True
SEED = 2026
USE_AMP = True
LAMBDA_L1 = 100.0

GAN_LOSS = "bce"
BETA1 = 0.5
BETA2 = 0.999
LATENT_DIM = 16
LAMBDA_DIVERSITY = 0.05
INDEPENDENT_LEARNING_RATE_RUNS = True

# %%
rasterio = None


def ensure_rasterio() -> None:
    global rasterio
    try:
        import rasterio as _rasterio
    except ImportError:
        if not INSTALL_RASTERIO_IF_MISSING:
            raise
        print("Installing rasterio in this Colab runtime...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "rasterio"])
        import rasterio as _rasterio
    rasterio = _rasterio


def maybe_mount_drive() -> None:
    if not MOUNT_GOOGLE_DRIVE:
        return
    try:
        from google.colab import drive
    except ImportError:
        print("google.colab is unavailable; skipping Drive mount.")
        return
    drive.mount("/content/drive")


def directory_has_tifs(path: Path) -> bool:
    return path.exists() and any(path.glob("*.tif*"))


def expected_data_ready() -> bool:
    return directory_has_tifs(Path(CONDITION_DIR)) and directory_has_tifs(Path(TARGET_DIR))


def maybe_extract_archive() -> None:
    if expected_data_ready():
        print(f"Using existing extracted folders: {CONDITION_DIR} and {TARGET_DIR}")
        return
    if not EXTRACT_ARCHIVE_IF_NEEDED:
        return
    archive_path = Path(DRIVE_ARCHIVE_ZIP)
    if not archive_path.exists():
        print(f"Archive not found: {archive_path}")
        print("Edit DRIVE_ARCHIVE_ZIP, CONDITION_DIR, or TARGET_DIR before training.")
        return
    archive_to_extract = archive_path
    if COPY_ARCHIVE_TO_LOCAL_BEFORE_EXTRACT:
        local_archive_path = Path(LOCAL_ARCHIVE_ZIP)
        if not local_archive_path.exists() or local_archive_path.stat().st_size != archive_path.stat().st_size:
            local_archive_path.parent.mkdir(parents=True, exist_ok=True)
            print(f"Copying archive from Drive to local runtime: {local_archive_path}")
            shutil.copy2(archive_path, local_archive_path)
        archive_to_extract = local_archive_path
    extract_dir = Path(EXTRACT_DIR)
    extract_dir.mkdir(parents=True, exist_ok=True)
    print(f"Extracting {archive_to_extract} to {extract_dir}...")
    with zipfile.ZipFile(archive_to_extract) as zf:
        zf.extractall(extract_dir)
    print("Archive extraction complete.")


def set_seed(seed: int) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def worker_init_fn(worker_id: int) -> None:
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed + worker_id)
    random.seed(worker_seed + worker_id)


def format_lr(value: float) -> str:
    return f"{value:g}".replace(".", "p")


def output_base_dir() -> Path:
    out = Path(OUTPUT_ROOT) / OUTPUT_SUBDIR
    out.mkdir(parents=True, exist_ok=True)
    return out


def output_run_dir(learning_rate: float, run_seed: int) -> Path:
    out = output_base_dir() / f"lr_{format_lr(learning_rate)}_seed_{run_seed}"
    out.mkdir(parents=True, exist_ok=True)
    return out


def list_tifs(folder: Path) -> set:
    return {path.name for path in folder.iterdir() if path.suffix.lower() in {".tif", ".tiff"}}


def read_raster(path: Path) -> np.ndarray:
    if rasterio is None:
        ensure_rasterio()
    with rasterio.open(path) as src:
        return src.read(1)


def should_use_amp(device: torch.device) -> bool:
    if not USE_AMP or device.type != "cuda":
        return False
    major, _minor = torch.cuda.get_device_capability()
    if major < 7:
        print("Disabling AMP for this GPU because compute capability is below 7.0.")
        return False
    return True

# %%
def encode_lulc_raw(arr: np.ndarray) -> np.ndarray:
    arr = arr.astype(np.float32)
    arr[(arr < 0) | (arr > 95)] = 0
    return ((arr / 95.0) * 2.0 - 1.0)[None, :, :].astype(np.float32)


def encode_lulc_onehot(arr: np.ndarray, classes: Iterable[int]) -> np.ndarray:
    arr = arr.astype(np.int16)
    channels = [(arr == cls).astype(np.float32) for cls in classes]
    return np.stack(channels, axis=0)


def encode_bf_unit(arr: np.ndarray) -> np.ndarray:
    arr = arr.astype(np.float32)
    arr = np.nan_to_num(arr, nan=0.0, posinf=1.0, neginf=0.0)
    return np.clip(arr, 0.0, 1.0)


def encode_bf_scaled(arr: np.ndarray) -> np.ndarray:
    return ((encode_bf_unit(arr) * 2.0) - 1.0)[None, :, :].astype(np.float32)


def height_to_meters(arr: np.ndarray, units: str) -> np.ndarray:
    arr = arr.astype(np.float32)
    if units == "feet":
        arr = arr * 0.3048
    elif units != "meters":
        raise ValueError("HEIGHT_UNITS must be 'feet' or 'meters'.")
    return arr


def encode_height_log1p(arr: np.ndarray, units: str, max_height_m: float) -> np.ndarray:
    arr = height_to_meters(arr, units)
    arr = np.nan_to_num(arr, nan=0.0, posinf=max_height_m, neginf=0.0)
    arr = np.clip(arr, 0.0, max_height_m)
    scaled = (np.log1p(arr) / np.log1p(max_height_m)) * 2.0 - 1.0
    return scaled[None, :, :].astype(np.float32)


def decode_height_log1p(scaled: np.ndarray, max_height_m: float) -> np.ndarray:
    clipped = np.clip(scaled, -1.0, 1.0)
    return np.expm1((clipped + 1.0) * np.log1p(max_height_m) / 2.0)


def encode_condition(arr: np.ndarray) -> np.ndarray:
    if CONDITION_KIND == "lulc":
        if LULC_MODE == "onehot":
            return encode_lulc_onehot(arr, NLCD_CLASSES)
        return encode_lulc_raw(arr)
    if CONDITION_KIND == "bf":
        return encode_bf_scaled(arr)
    raise ValueError(f"Unknown CONDITION_KIND: {CONDITION_KIND}")


def encode_target(arr: np.ndarray) -> np.ndarray:
    if TARGET_KIND == "bf":
        return encode_bf_scaled(arr)
    if TARGET_KIND == "height":
        return encode_height_log1p(arr, HEIGHT_UNITS, MAX_HEIGHT_M)
    raise ValueError(f"Unknown TARGET_KIND: {TARGET_KIND}")


class RasterPairDataset(Dataset):
    def __init__(self, condition_dir: Path, target_dir: Path, cache_data: bool = False) -> None:
        self.condition_dir = condition_dir
        self.target_dir = target_dir
        common = sorted(list_tifs(condition_dir) & list_tifs(target_dir))
        if not common:
            raise ValueError(f"No matching .tif files found in {condition_dir} and {target_dir}")
        self.files = common
        self.cache = None
        if cache_data:
            print("Caching all tiles in RAM...")
            self.cache = [self._load_item(filename) for filename in self.files]

    def __len__(self) -> int:
        return len(self.files)

    def _load_item(self, filename: str):
        cond = encode_condition(read_raster(self.condition_dir / filename))
        target = encode_target(read_raster(self.target_dir / filename))
        if cond.shape[-2:] != target.shape[-2:]:
            raise ValueError(f"Shape mismatch for {filename}: {cond.shape} vs {target.shape}")
        return torch.from_numpy(cond), torch.from_numpy(target)

    def __getitem__(self, idx: int):
        if self.cache is not None:
            return self.cache[idx]
        return self._load_item(self.files[idx])

# %%
class EncoderBlock(nn.Module):
    def __init__(self, in_channels: int, out_channels: int, norm: bool = True) -> None:
        super().__init__()
        layers = [nn.Conv2d(in_channels, out_channels, kernel_size=4, stride=2, padding=1, bias=not norm)]
        if norm:
            layers.append(nn.BatchNorm2d(out_channels))
        layers.append(nn.LeakyReLU(0.2, inplace=False))
        self.block = nn.Sequential(*layers)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.block(x)


class DecoderBlock(nn.Module):
    def __init__(self, in_channels: int, out_channels: int, latent_dim: int, dropout: bool = False) -> None:
        super().__init__()
        self.relu = nn.ReLU(inplace=False)
        self.deconv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=4, stride=2, padding=1, bias=False)
        self.bn = nn.BatchNorm2d(out_channels)
        self.dropout = nn.Dropout2d(0.5) if dropout else None
        self.film = nn.Linear(latent_dim, out_channels * 2)
        nn.init.normal_(self.film.weight, mean=0.0, std=0.02)
        nn.init.zeros_(self.film.bias)

    def forward(self, x: torch.Tensor, z: torch.Tensor) -> torch.Tensor:
        x = self.relu(x)
        x = self.deconv(x)
        x = self.bn(x)
        gamma, beta = self.film(z).chunk(2, dim=1)
        x = x * (1.0 + gamma[:, :, None, None]) + beta[:, :, None, None]
        if self.dropout is not None:
            x = self.dropout(x)
        return x


class GeneratorMultiRandom(nn.Module):
    def __init__(self, condition_channels: int, latent_dim: int = 16) -> None:
        super().__init__()
        self.latent_dim = latent_dim
        self.encoder1 = EncoderBlock(condition_channels + latent_dim, 64, norm=False)
        self.encoder2 = EncoderBlock(64, 128)
        self.encoder3 = EncoderBlock(128, 256)
        self.encoder4 = EncoderBlock(256, 512)
        self.encoder5 = EncoderBlock(512, 512)
        self.encoder6 = EncoderBlock(512, 512)
        self.encoder7 = EncoderBlock(512, 512)
        self.encoder8 = EncoderBlock(512, 512, norm=False)
        self.decoder8 = DecoderBlock(512, 512, latent_dim, dropout=True)
        self.decoder7 = DecoderBlock(1024, 512, latent_dim, dropout=True)
        self.decoder6 = DecoderBlock(1024, 512, latent_dim, dropout=True)
        self.decoder5 = DecoderBlock(1024, 512, latent_dim)
        self.decoder4 = DecoderBlock(1024, 256, latent_dim)
        self.decoder3 = DecoderBlock(512, 128, latent_dim)
        self.decoder2 = DecoderBlock(256, 64, latent_dim)
        self.decoder1 = nn.Sequential(nn.ReLU(inplace=False), nn.ConvTranspose2d(128, 1, kernel_size=4, stride=2, padding=1), nn.Tanh())

    def forward(self, cond: torch.Tensor, z: torch.Tensor) -> torch.Tensor:
        z_img = z[:, :, None, None].expand(-1, -1, cond.size(2), cond.size(3))
        x = torch.cat([cond, z_img], dim=1)
        e1 = self.encoder1(x)
        e2 = self.encoder2(e1)
        e3 = self.encoder3(e2)
        e4 = self.encoder4(e3)
        e5 = self.encoder5(e4)
        e6 = self.encoder6(e5)
        e7 = self.encoder7(e6)
        e8 = self.encoder8(e7)
        d8 = torch.cat([self.decoder8(e8, z), e7], dim=1)
        d7 = torch.cat([self.decoder7(d8, z), e6], dim=1)
        d6 = torch.cat([self.decoder6(d7, z), e5], dim=1)
        d5 = torch.cat([self.decoder5(d6, z), e4], dim=1)
        d4 = torch.cat([self.decoder4(d5, z), e3], dim=1)
        d3 = torch.cat([self.decoder3(d4, z), e2], dim=1)
        d2 = torch.cat([self.decoder2(d3, z), e1], dim=1)
        return self.decoder1(d2)


class DiscriminatorBlock(nn.Module):
    def __init__(self, in_channels: int, out_channels: int, norm: bool = True) -> None:
        super().__init__()
        layers = [nn.Conv2d(in_channels, out_channels, kernel_size=4, stride=2, padding=1, bias=not norm)]
        if norm:
            layers.append(nn.InstanceNorm2d(out_channels, affine=True))
        layers.append(nn.LeakyReLU(0.2, inplace=False))
        self.block = nn.Sequential(*layers)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.block(x)


class PatchDiscriminator(nn.Module):
    def __init__(self, condition_channels: int) -> None:
        super().__init__()
        self.block1 = DiscriminatorBlock(condition_channels + 1, 64, norm=False)
        self.block2 = DiscriminatorBlock(64, 128)
        self.block3 = DiscriminatorBlock(128, 256)
        self.block4 = DiscriminatorBlock(256, 512)
        self.final = nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=1)

    def forward(self, target: torch.Tensor, cond: torch.Tensor) -> torch.Tensor:
        x = torch.cat([target, cond], dim=1)
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        return self.final(x)

# %%
def adversarial_loss(pred: torch.Tensor, is_real: bool, loss_type: str) -> torch.Tensor:
    target = torch.ones_like(pred) if is_real else torch.zeros_like(pred)
    if loss_type == "bce":
        return F.binary_cross_entropy_with_logits(pred, target)
    if loss_type == "lsgan":
        return F.mse_loss(pred, target)
    raise ValueError(f"Unknown GAN_LOSS: {loss_type}")

# %%
def mode_seeking_loss(fake_a: torch.Tensor, fake_b: torch.Tensor, z_a: torch.Tensor, z_b: torch.Tensor, eps: float = 1e-6) -> torch.Tensor:
    output_dist = torch.mean(torch.abs(fake_a - fake_b), dim=(1, 2, 3))
    latent_dist = torch.mean(torch.abs(z_a - z_b), dim=1)
    return -torch.mean(output_dist / (latent_dist + eps))


@dataclass
class EpochMetrics:
    epoch: int
    lr: float
    d_loss: float
    g_loss: float
    adv_loss: float
    l1_loss: float
    diversity_loss: float
    seconds: float


def train_one_learning_rate(dataset: RasterPairDataset, condition_channels: int, learning_rate: float, run_seed: int) -> None:
    set_seed(run_seed)
    run_dir = output_run_dir(learning_rate, run_seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    use_amp = should_use_amp(device)
    generator = GeneratorMultiRandom(condition_channels=condition_channels, latent_dim=LATENT_DIM).to(device)
    discriminator = PatchDiscriminator(condition_channels=condition_channels).to(device)
    g_optimizer = torch.optim.Adam(generator.parameters(), lr=learning_rate, betas=(BETA1, BETA2))
    d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=learning_rate, betas=(BETA1, BETA2))
    loader_generator = torch.Generator(); loader_generator.manual_seed(run_seed)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=(device.type == "cuda"), persistent_workers=NUM_WORKERS > 0, worker_init_fn=worker_init_fn, generator=loader_generator)
    scaler = torch.amp.GradScaler("cuda", enabled=use_amp)
    metadata = {
        "model_class": MODEL_CLASS,
        "target_kind": TARGET_KIND,
        "condition_kind": CONDITION_KIND,
        "learning_rate": learning_rate,
        "seed": run_seed,
        "condition_channels": condition_channels,
        "latent_dim": LATENT_DIM,
        "independent_learning_rate_runs": True,
        "diversity_loss": "mode_seeking",
        "lambda_diversity": LAMBDA_DIVERSITY,
        "height_scaling": "log1p/expm1" if TARGET_KIND == "height" else None,
        "output_dir": str(run_dir),
    }
    with (run_dir / "metadata.json").open("w", encoding="utf-8") as f:
        json.dump(metadata, f, indent=2, sort_keys=True)
    metrics = []
    for epoch in range(1, EPOCHS + 1):
        generator.train(); discriminator.train()
        start = time.time()
        d_losses = []; g_losses = []; adv_losses = []; l1_losses = []; div_losses = []
        for cond, real in dataloader:
            cond = cond.to(device=device, dtype=torch.float32, non_blocking=True)
            real = real.to(device=device, dtype=torch.float32, non_blocking=True)
            batch_size = cond.size(0)
            d_optimizer.zero_grad(set_to_none=True)
            with torch.no_grad():
                z_d = torch.randn(batch_size, LATENT_DIM, device=device)
                fake_d = generator(cond, z_d)
            with torch.amp.autocast("cuda", enabled=use_amp):
                real_pred = discriminator(real, cond)
                fake_pred = discriminator(fake_d.detach(), cond)
                d_loss = 0.5 * (adversarial_loss(real_pred, True, GAN_LOSS) + adversarial_loss(fake_pred, False, GAN_LOSS))
            scaler.scale(d_loss).backward(); scaler.step(d_optimizer)
            g_optimizer.zero_grad(set_to_none=True)
            z_a = torch.randn(batch_size, LATENT_DIM, device=device)
            z_b = torch.randn(batch_size, LATENT_DIM, device=device)
            with torch.amp.autocast("cuda", enabled=use_amp):
                fake_a = generator(cond, z_a)
                fake_b = generator(cond, z_b)
                pred_a = discriminator(fake_a, cond)
                pred_b = discriminator(fake_b, cond)
                adv_loss = 0.5 * (adversarial_loss(pred_a, True, GAN_LOSS) + adversarial_loss(pred_b, True, GAN_LOSS))
                l1_loss = 0.5 * (F.l1_loss(fake_a, real) + F.l1_loss(fake_b, real))
                div_loss = mode_seeking_loss(fake_a, fake_b, z_a, z_b)
                g_loss = adv_loss + LAMBDA_L1 * l1_loss + LAMBDA_DIVERSITY * div_loss
            scaler.scale(g_loss).backward(); scaler.step(g_optimizer); scaler.update()
            d_losses.append(float(d_loss.detach().cpu()))
            g_losses.append(float(g_loss.detach().cpu()))
            adv_losses.append(float(adv_loss.detach().cpu()))
            l1_losses.append(float(l1_loss.detach().cpu()))
            div_losses.append(float(div_loss.detach().cpu()))
        row = EpochMetrics(epoch=epoch, lr=learning_rate, d_loss=float(np.mean(d_losses)), g_loss=float(np.mean(g_losses)), adv_loss=float(np.mean(adv_losses)), l1_loss=float(np.mean(l1_losses)), diversity_loss=float(np.mean(div_losses)), seconds=time.time() - start)
        metrics.append(row)
        if epoch % PRINT_EVERY == 0 or epoch == 1 or epoch == EPOCHS:
            print(f"[{MODEL_CLASS} lr={learning_rate:g}] epoch {epoch:04d}/{EPOCHS} D={row.d_loss:.4f} G={row.g_loss:.4f} adv={row.adv_loss:.4f} L1={row.l1_loss:.4f} div={row.diversity_loss:.4f} sec={row.seconds:.1f}", flush=True)
        if epoch % SAVE_EVERY == 0 or epoch == EPOCHS:
            torch.save(generator.state_dict(), run_dir / f"generator_epoch_{epoch:04d}.pth")
            torch.save(discriminator.state_dict(), run_dir / f"discriminator_epoch_{epoch:04d}.pth")
    with (run_dir / "losses.csv").open("w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=list(asdict(metrics[0]).keys()))
        writer.writeheader()
        for row in metrics:
            writer.writerow(asdict(row))


def main() -> None:
    print(f"Using torch {torch.__version__}")
    if torch.cuda.is_available():
        print(torch.cuda.get_device_name(0)); torch.backends.cudnn.benchmark = True
    maybe_mount_drive(); maybe_extract_archive(); ensure_rasterio()
    condition_channels = len(NLCD_CLASSES) if CONDITION_KIND == "lulc" and LULC_MODE == "onehot" else 1
    dataset = RasterPairDataset(Path(CONDITION_DIR), Path(TARGET_DIR), cache_data=CACHE_DATA_IN_RAM)
    print(f"Found {len(dataset)} matched training tiles.")
    print(f"Output base: {output_base_dir()}")
    for idx, lr in enumerate(LEARNING_RATES):
        train_one_learning_rate(dataset, condition_channels, lr, SEED + idx * 1000)
    print("Training complete.")

# %%
# Start this notebook's training/fitting job.
main()
# Out:
# Using torch 2.11.0+cu128
# NVIDIA A100-SXM4-80GB
# Mounted at /content/drive
# Copying archive from Drive to local runtime: /content/Archive.zip
# Extracting /content/Archive.zip to /home...
# Archive extraction complete.
# Caching all tiles in RAM...
# Found 8000 matched training tiles.
# Output base: /content/drive/My Drive/IM3/EvalP1/codev3/3_BF_cGANMultiRandomDiversity
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0001/1000 D=0.2130 G=48.0025 adv=2.5727 L1=0.4545 div=-0.3046 sec=56.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0025/1000 D=0.2298 G=28.4882 adv=4.2766 L1=0.2421 div=-0.0608 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0050/1000 D=0.3000 G=25.7262 adv=2.9293 L1=0.2280 div=-0.0561 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0075/1000 D=0.2612 G=25.1103 adv=2.9871 L1=0.2213 div=-0.0549 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0100/1000 D=0.2981 G=23.2932 adv=2.4723 L1=0.2082 div=-0.0478 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0125/1000 D=0.2558 G=23.8985 adv=3.3378 L1=0.2056 div=-0.0442 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0150/1000 D=0.2869 G=22.8164 adv=2.7602 L1=0.2006 div=-0.0446 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0175/1000 D=0.2854 G=22.5717 adv=2.8390 L1=0.1973 div=-0.0445 sec=16.4
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0200/1000 D=0.2984 G=22.2938 adv=2.8948 L1=0.1940 div=-0.0438 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0225/1000 D=0.3093 G=22.0017 adv=2.8136 L1=0.1919 div=-0.0437 sec=16.4
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0250/1000 D=0.2844 G=21.6465 adv=2.6736 L1=0.1898 div=-0.0425 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0275/1000 D=0.3288 G=21.3764 adv=2.5963 L1=0.1878 div=-0.0414 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0300/1000 D=0.3097 G=21.4209 adv=2.7096 L1=0.1871 div=-0.0416 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0325/1000 D=0.3491 G=20.9148 adv=2.3804 L1=0.1854 div=-0.0402 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0350/1000 D=0.3342 G=20.8622 adv=2.4086 L1=0.1846 div=-0.0396 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0375/1000 D=0.3717 G=20.9163 adv=2.5032 L1=0.1842 div=-0.0394 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0400/1000 D=0.3099 G=20.8505 adv=2.4989 L1=0.1835 div=-0.0397 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0425/1000 D=0.3415 G=20.7225 adv=2.4363 L1=0.1829 div=-0.0386 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0450/1000 D=0.3164 G=20.9420 adv=2.6765 L1=0.1827 div=-0.0388 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0475/1000 D=0.3394 G=20.5710 adv=2.3959 L1=0.1818 div=-0.0378 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0500/1000 D=0.3192 G=20.3964 adv=2.3114 L1=0.1809 div=-0.0373 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0525/1000 D=0.3582 G=20.6971 adv=2.5556 L1=0.1814 div=-0.0373 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0550/1000 D=0.3759 G=20.6193 adv=2.5552 L1=0.1807 div=-0.0373 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0575/1000 D=0.3252 G=20.5928 adv=2.5649 L1=0.1803 div=-0.0370 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0600/1000 D=0.1286 G=29.7358 adv=5.5785 L1=0.2416 div=-0.0508 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0625/1000 D=0.0999 G=28.0703 adv=6.1166 L1=0.2196 div=-0.0367 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0650/1000 D=0.0830 G=27.2949 adv=5.6318 L1=0.2167 div=-0.0377 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0675/1000 D=0.1133 G=26.8366 adv=5.5955 L1=0.2124 div=-0.0373 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0700/1000 D=0.3975 G=27.1322 adv=6.2780 L1=0.2086 div=-0.0410 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0725/1000 D=0.0891 G=25.9288 adv=4.9816 L1=0.2095 div=-0.0426 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0750/1000 D=0.5013 G=25.4951 adv=5.0310 L1=0.2047 div=-0.0444 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0775/1000 D=0.2158 G=23.5412 adv=3.7249 L1=0.1982 div=-0.0425 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0800/1000 D=0.2959 G=22.5733 adv=3.0725 L1=0.1950 div=-0.0401 sec=16.0
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0825/1000 D=0.3417 G=21.7614 adv=2.5982 L1=0.1917 div=-0.0380 sec=16.0
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0850/1000 D=0.3845 G=21.2434 adv=2.3412 L1=0.1890 div=-0.0369 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0875/1000 D=0.3953 G=21.1063 adv=2.3558 L1=0.1875 div=-0.0365 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0900/1000 D=0.4232 G=20.4699 adv=1.9572 L1=0.1851 div=-0.0356 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0925/1000 D=0.4380 G=20.4494 adv=2.0548 L1=0.1840 div=-0.0356 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0950/1000 D=0.4320 G=20.4699 adv=2.1690 L1=0.1830 div=-0.0356 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 0975/1000 D=0.3745 G=20.4617 adv=2.2405 L1=0.1822 div=-0.0357 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0001] epoch 1000/1000 D=0.3759 G=20.6344 adv=2.4335 L1=0.1820 div=-0.0351 sec=16.0
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0001/1000 D=0.1477 G=39.8752 adv=3.2976 L1=0.3659 div=-0.2262 sec=16.9
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0025/1000 D=0.2951 G=26.3460 adv=3.2624 L1=0.2309 div=-0.0455 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0050/1000 D=0.3710 G=23.9127 adv=2.4701 L1=0.2144 div=-0.0442 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0075/1000 D=0.3255 G=23.6492 adv=3.0483 L1=0.2060 div=-0.0399 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0100/1000 D=0.3078 G=22.1769 adv=2.5180 L1=0.1966 div=-0.0418 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0125/1000 D=0.3513 G=21.6277 adv=2.5613 L1=0.1907 div=-0.0418 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0150/1000 D=0.3970 G=20.7772 adv=2.2926 L1=0.1849 div=-0.0418 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0175/1000 D=0.4186 G=20.1990 adv=2.1047 L1=0.1810 div=-0.0400 sec=16.0
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0200/1000 D=0.4190 G=20.0582 adv=2.2106 L1=0.1785 div=-0.0403 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0225/1000 D=0.4358 G=19.4745 adv=1.9178 L1=0.1756 div=-0.0398 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0250/1000 D=0.4501 G=19.3740 adv=2.0211 L1=0.1735 div=-0.0393 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0275/1000 D=0.4866 G=19.1123 adv=1.9772 L1=0.1714 div=-0.0386 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0300/1000 D=0.4558 G=18.8988 adv=1.8663 L1=0.1703 div=-0.0384 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0325/1000 D=0.4485 G=18.6795 adv=1.7658 L1=0.1692 div=-0.0384 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0350/1000 D=0.4604 G=18.7509 adv=1.8947 L1=0.1686 div=-0.0379 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0375/1000 D=0.6714 G=18.5180 adv=1.9227 L1=0.1660 div=-0.0371 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0400/1000 D=0.4432 G=18.3820 adv=1.7351 L1=0.1665 div=-0.0375 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0425/1000 D=0.4554 G=18.4821 adv=1.8512 L1=0.1663 div=-0.0371 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0450/1000 D=0.4486 G=18.5102 adv=1.9140 L1=0.1660 div=-0.0387 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0475/1000 D=0.4214 G=18.3858 adv=1.8339 L1=0.1655 div=-0.0369 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0500/1000 D=0.4380 G=18.1999 adv=1.7454 L1=0.1646 div=-0.0366 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0525/1000 D=0.4387 G=18.2539 adv=1.7829 L1=0.1647 div=-0.0365 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0550/1000 D=0.4396 G=18.3050 adv=1.8671 L1=0.1644 div=-0.0358 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0575/1000 D=0.4453 G=18.2061 adv=1.8222 L1=0.1639 div=-0.0356 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0600/1000 D=0.4445 G=18.2004 adv=1.8351 L1=0.1637 div=-0.0361 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0625/1000 D=0.4381 G=18.2073 adv=1.8561 L1=0.1635 div=-0.0351 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0650/1000 D=0.4398 G=18.1309 adv=1.8085 L1=0.1632 div=-0.0353 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0675/1000 D=0.4390 G=17.7812 adv=1.5630 L1=0.1622 div=-0.0343 sec=16.5
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0700/1000 D=0.4590 G=17.5407 adv=1.4253 L1=0.1612 div=-0.0335 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0725/1000 D=0.4313 G=18.0617 adv=1.7843 L1=0.1628 div=-0.0344 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0750/1000 D=0.4595 G=18.1830 adv=1.9147 L1=0.1627 div=-0.0339 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0775/1000 D=0.4104 G=18.1717 adv=1.8741 L1=0.1630 div=-0.0341 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0800/1000 D=0.4143 G=18.1653 adv=1.8953 L1=0.1627 div=-0.0339 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0825/1000 D=0.4349 G=18.1029 adv=1.8547 L1=0.1625 div=-0.0334 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0850/1000 D=0.4996 G=17.7508 adv=1.6292 L1=0.1612 div=-0.0329 sec=16.0
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0875/1000 D=0.4276 G=18.1280 adv=1.8715 L1=0.1626 div=-0.0336 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0900/1000 D=0.4537 G=18.0665 adv=1.8506 L1=0.1622 div=-0.0327 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0925/1000 D=0.4225 G=18.0053 adv=1.7880 L1=0.1622 div=-0.0326 sec=16.5
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0950/1000 D=0.5092 G=18.1813 adv=1.9962 L1=0.1619 div=-0.0328 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 0975/1000 D=0.4275 G=18.0748 adv=1.8529 L1=0.1622 div=-0.0324 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0002] epoch 1000/1000 D=0.4191 G=18.0700 adv=1.8478 L1=0.1622 div=-0.0324 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0001/1000 D=0.1629 G=37.4059 adv=3.2988 L1=0.3412 div=-0.1862 sec=16.8
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0025/1000 D=0.4129 G=23.8660 adv=2.7057 L1=0.2116 div=-0.0405 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0050/1000 D=0.3741 G=22.9611 adv=3.4747 L1=0.1949 div=-0.0371 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0075/1000 D=0.4100 G=20.9053 adv=2.6064 L1=0.1830 div=-0.0431 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0100/1000 D=0.3843 G=20.0484 adv=2.3969 L1=0.1765 div=-0.0417 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0125/1000 D=0.4212 G=19.4578 adv=2.2367 L1=0.1722 div=-0.0403 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0150/1000 D=0.4349 G=19.0050 adv=2.1435 L1=0.1686 div=-0.0387 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0175/1000 D=0.4811 G=18.5416 adv=2.0049 L1=0.1654 div=-0.0377 sec=16.4
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0200/1000 D=0.4494 G=18.3845 adv=1.9761 L1=0.1641 div=-0.0371 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0225/1000 D=0.4336 G=18.0477 adv=1.8236 L1=0.1623 div=-0.0361 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0250/1000 D=0.5709 G=18.7320 adv=2.3920 L1=0.1634 div=-0.0428 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0275/1000 D=0.3384 G=19.2325 adv=2.4601 L1=0.1678 div=-0.0570 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0300/1000 D=0.4471 G=17.9656 adv=1.9765 L1=0.1599 div=-0.0346 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0325/1000 D=0.4532 G=17.8583 adv=1.9427 L1=0.1592 div=-0.0341 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0350/1000 D=0.4332 G=17.9096 adv=2.0149 L1=0.1590 div=-0.0337 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0375/1000 D=0.4044 G=17.9691 adv=2.0665 L1=0.1590 div=-0.0343 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0400/1000 D=0.4046 G=17.8865 adv=2.0220 L1=0.1587 div=-0.0345 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0425/1000 D=0.4107 G=17.9487 adv=2.0697 L1=0.1588 div=-0.0342 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0450/1000 D=0.4456 G=17.6358 adv=1.8688 L1=0.1577 div=-0.0322 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0475/1000 D=0.4463 G=17.8158 adv=2.0337 L1=0.1578 div=-0.0325 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0500/1000 D=0.3120 G=18.5797 adv=2.4985 L1=0.1608 div=-0.0447 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0525/1000 D=0.4455 G=17.9062 adv=2.1174 L1=0.1579 div=-0.0320 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0550/1000 D=0.4422 G=17.6461 adv=1.9167 L1=0.1573 div=-0.0310 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0575/1000 D=0.4341 G=17.6055 adv=1.8991 L1=0.1571 div=-0.0309 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0600/1000 D=0.4443 G=18.0707 adv=2.2730 L1=0.1580 div=-0.0313 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0625/1000 D=0.4470 G=17.6331 adv=1.9091 L1=0.1573 div=-0.0304 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0650/1000 D=0.4107 G=17.7789 adv=2.0124 L1=0.1577 div=-0.0321 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0675/1000 D=0.3661 G=18.0785 adv=2.2564 L1=0.1582 div=-0.0308 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0700/1000 D=0.4124 G=17.7971 adv=2.0382 L1=0.1576 div=-0.0301 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0725/1000 D=0.4455 G=17.6302 adv=1.9006 L1=0.1573 div=-0.0304 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0750/1000 D=0.3804 G=17.9898 adv=2.1636 L1=0.1583 div=-0.0317 sec=16.5
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0775/1000 D=0.4005 G=17.9456 adv=2.1295 L1=0.1582 div=-0.0308 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0800/1000 D=0.4100 G=18.0971 adv=2.2676 L1=0.1583 div=-0.0299 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0825/1000 D=0.4591 G=17.8407 adv=2.0757 L1=0.1577 div=-0.0290 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0850/1000 D=0.4058 G=17.7350 adv=1.9841 L1=0.1575 div=-0.0286 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0875/1000 D=0.4031 G=17.8188 adv=2.0284 L1=0.1579 div=-0.0287 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0900/1000 D=0.3232 G=18.1875 adv=2.3271 L1=0.1586 div=-0.0293 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0925/1000 D=0.3898 G=17.6166 adv=1.8609 L1=0.1576 div=-0.0282 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0950/1000 D=0.3381 G=18.3250 adv=2.4356 L1=0.1589 div=-0.0289 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 0975/1000 D=0.2524 G=18.6439 adv=2.6773 L1=0.1597 div=-0.0294 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.0005] epoch 1000/1000 D=0.7276 G=18.0766 adv=2.2906 L1=0.1579 div=-0.0280 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0001/1000 D=0.3652 G=37.7790 adv=2.9172 L1=0.3487 div=-0.1816 sec=16.8
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0025/1000 D=0.5257 G=22.0968 adv=1.5014 L1=0.2060 div=-0.0327 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0050/1000 D=0.4703 G=19.9915 adv=2.1399 L1=0.1785 div=-0.0397 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0075/1000 D=0.4527 G=20.1424 adv=2.4861 L1=0.1766 div=-0.0529 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0100/1000 D=0.4462 G=18.6631 adv=2.1637 L1=0.1650 div=-0.0387 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0125/1000 D=0.6425 G=17.9981 adv=1.9844 L1=0.1602 div=-0.0362 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0150/1000 D=0.4708 G=17.7483 adv=1.8092 L1=0.1594 div=-0.0351 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0175/1000 D=0.5216 G=17.5796 adv=1.8415 L1=0.1574 div=-0.0343 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0200/1000 D=0.4254 G=19.3429 adv=2.6818 L1=0.1666 div=-0.0534 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0225/1000 D=0.4592 G=17.6937 adv=2.0706 L1=0.1562 div=-0.0353 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0250/1000 D=0.4334 G=17.4831 adv=1.9176 L1=0.1557 div=-0.0348 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0275/1000 D=0.4102 G=17.5522 adv=2.0239 L1=0.1553 div=-0.0347 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0300/1000 D=0.4593 G=17.2861 adv=1.8509 L1=0.1544 div=-0.0328 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0325/1000 D=0.4775 G=17.4113 adv=1.9930 L1=0.1542 div=-0.0322 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0350/1000 D=0.4588 G=17.3734 adv=1.9801 L1=0.1539 div=-0.0319 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0375/1000 D=0.3917 G=17.6704 adv=2.2040 L1=0.1547 div=-0.0327 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0400/1000 D=0.4048 G=17.2935 adv=1.9375 L1=0.1536 div=-0.0316 sec=16.6
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0425/1000 D=0.5299 G=17.0946 adv=1.8040 L1=0.1529 div=-0.0295 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0450/1000 D=0.4354 G=17.7493 adv=2.3014 L1=0.1545 div=-0.0314 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0475/1000 D=0.4246 G=17.1196 adv=1.8425 L1=0.1528 div=-0.0301 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0500/1000 D=0.3735 G=17.3876 adv=2.0092 L1=0.1538 div=-0.0302 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0525/1000 D=0.3900 G=17.5027 adv=2.1310 L1=0.1537 div=-0.0297 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0550/1000 D=0.4454 G=16.9698 adv=1.6877 L1=0.1528 div=-0.0280 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0575/1000 D=0.4218 G=17.0830 adv=1.7582 L1=0.1533 div=-0.0279 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0600/1000 D=0.3663 G=17.5641 adv=2.1193 L1=0.1545 div=-0.0290 sec=16.0
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0625/1000 D=0.3994 G=17.5306 adv=2.0976 L1=0.1543 div=-0.0279 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0650/1000 D=0.5213 G=17.4526 adv=2.0540 L1=0.1540 div=-0.0275 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0675/1000 D=0.3626 G=17.7968 adv=2.3199 L1=0.1548 div=-0.0283 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0700/1000 D=0.2691 G=18.6057 adv=2.9590 L1=0.1565 div=-0.0296 sec=16.4
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0725/1000 D=0.1193 G=19.7995 adv=3.8742 L1=0.1593 div=-0.0392 sec=16.4
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0750/1000 D=0.4109 G=18.0667 adv=2.4509 L1=0.1562 div=-0.0272 sec=16.0
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0775/1000 D=0.7565 G=17.9129 adv=2.3806 L1=0.1553 div=-0.0266 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0800/1000 D=0.0950 G=20.2679 adv=4.2360 L1=0.1603 div=-0.0396 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0825/1000 D=0.3554 G=18.3844 adv=2.6235 L1=0.1576 div=-0.0267 sec=16.1
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0850/1000 D=0.4629 G=18.1853 adv=2.4624 L1=0.1572 div=-0.0266 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0875/1000 D=0.4352 G=18.2915 adv=2.5523 L1=0.1574 div=-0.0268 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0900/1000 D=0.2440 G=18.4675 adv=2.6683 L1=0.1580 div=-0.0272 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0925/1000 D=0.3139 G=18.1117 adv=2.3662 L1=0.1575 div=-0.0256 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0950/1000 D=0.3272 G=18.1950 adv=2.4258 L1=0.1577 div=-0.0259 sec=16.2
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 0975/1000 D=0.2000 G=18.8102 adv=2.9253 L1=0.1589 div=-0.0272 sec=16.3
# [3_BF_cGANMultiRandomDiversity lr=0.001] epoch 1000/1000 D=0.2251 G=18.5569 adv=2.6875 L1=0.1587 div=-0.0266 sec=16.3
# Training complete.
